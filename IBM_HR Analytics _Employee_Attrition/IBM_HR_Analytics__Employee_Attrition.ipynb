# %% [markdown]
# # 1. Data Collection

# %%
# Loud data -> (HR-Employee-Attrition.csv)

import pandas as pd

data = pd.read_csv("/content/HR-Employee-Attrition.csv")

# %% [markdown]
# # 2. Understanding the Data (EDA)
# ### Use statistical summaries and visualizations:
#
# * .describe(), .info(), value_counts() , head()
#
# ### Visuals: histograms, boxplots, heatmaps, pair plots
#
#
# ### Goal: Understand structure, distribution, anomalies.
# Check for:
#
# * Data types (int, float, object)
#
# * Missing values
#
# * Unique values per column
#
# * Skewed distributions(Outliers)
#
# * Correlation

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# # 3. Handling Missing Values
# * Drop rows/columns: df.dropna()
#
# * Imputation:
#
#     * Mean/median/mode for numerical
#
#     * Most frequent(mode)/fill with 'unknown' for categorical
#
# # 4. Handling duplicated Values
# * * Drop duplicated rows

# %%
data.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Select Key Features
# * Age
# * BusinessTravel
# * Department
# * JobSatisfaction
# * WorkLifeBalance
# * MonthlyIncome
# * YearsAtCompany
#
# # Target
# * Attrition

# %%
data = data[['Age', 'Attrition', 'BusinessTravel', 'Department', 'JobSatisfaction', 'WorkLifeBalance', 'MonthlyIncome', 'YearsAtCompany']]

# %%
data
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      41       Yes      Travel_Rarely                   Sales
# 1      49        No  Travel_Frequently  Research & Development
# 2      37       Yes      Travel_Rarely  Research & Development
# 3      33        No  Travel_Frequently  Research & Development
# 4      27        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 1465   36        No  Travel_Frequently  Research & Development
# 1466   39        No      Travel_Rarely  Research & Development
# 1467   27        No      Travel_Rarely  Research & Development
# 1468   49        No  Travel_Frequently                   Sales
# 1469   34        No      Travel_Rarely  Research & Development
#
#       JobSatisfaction  WorkLifeBalance  MonthlyIncome  YearsAtCompany
# 0                   4                1           5993               6
# ...

# %% [markdown]
# # split Data
# * Features
#     * numerical
#     * categorical
# * Target

# %%
# Separate features and target
Features = data.drop('Attrition', axis=1)
Target = data[['Attrition']]


# Identify numeric and categorical columns
numeric_features = Features.select_dtypes(include=['int64', 'float64'])
categorical_features = Features.select_dtypes(include=['object'])

print("\nNumeric Features:")
print(numeric_features.columns)
print("\nCategorical Features:")
print(categorical_features.columns)
print("\nTarget Variable:")
print(Target.value_counts())
# Out:
# Numeric Features:
# Index(['Age', 'JobSatisfaction', 'WorkLifeBalance', 'MonthlyIncome',
#        'YearsAtCompany'],
#       dtype='object')
#
# Categorical Features:
# Index(['BusinessTravel', 'Department'], dtype='object')
#
# Target Variable:
# Attrition
# No           1233
# Yes           237
# Name: count, dtype: int64

# %% [markdown]
# # 5. Handling Outliers
# * Z-score or IQR-based removal
#
# * Capping/clipping

# %% [markdown]
# # IQR-Based Outlier Removal
# ### IQR (Interquartile Range) = Q3 - Q1
# ### Data points below  Lower(Q1 - 1.5×IQR) or above Upper(Q3 + 1.5×IQR) are considered outliers.

# %%
# Handle outliers using IQR method

numeric_features_copy = numeric_features

for col in numeric_features.columns:
    Q1 = numeric_features_copy[col].quantile(0.25)
    Q3 = numeric_features_copy[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    numeric_features_copy = numeric_features_copy[(numeric_features_copy[col] >= lower) & (numeric_features_copy[col] <= upper)]

# %%
numeric_features_copy
# Out:
#       Age  JobSatisfaction  WorkLifeBalance  MonthlyIncome  YearsAtCompany
# 0      41                4                1           5993               6
# 1      49                2                3           5130              10
# 2      37                3                3           2090               0
# 3      33                3                3           2909               8
# 4      27                2                3           3468               2
# ...   ...              ...              ...            ...             ...
# 1465   36                4                3           2571               5
# 1466   39                1                3           9991               7
# 1467   27                2                3           6142               6
# 1468   49                2                2           5390               9
# 1469   34                3                4           4404               4
#
# [1304 rows x 5 columns]

# %%
numeric_features.boxplot()
# Out:
# <Axes: >

# %%
for col in numeric_features.columns:
    Q1 = numeric_features[col].quantile(0.25)
    Q3 = numeric_features[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    numeric_features[col] = numeric_features[col].clip(lower=lower, upper=upper)

# %%
numeric_features
# Out:
#       Age  JobSatisfaction  WorkLifeBalance  MonthlyIncome  YearsAtCompany
# 0      41                4                1           5993               6
# 1      49                2                3           5130              10
# 2      37                3                3           2090               0
# 3      33                3                3           2909               8
# 4      27                2                3           3468               2
# ...   ...              ...              ...            ...             ...
# 1465   36                4                3           2571               5
# 1466   39                1                3           9991               7
# 1467   27                2                3           6142               6
# 1468   49                2                2           5390               9
# 1469   34                3                4           4404               4
#
# [1470 rows x 5 columns]

# %%
numeric_features.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# # 6. Feature Scaling
# * Standardization (Z-score): StandardScaler (mean=0, std=1)
#
# * Normalization: MinMaxScaler (range 0 to 1)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
numeric_features_scaled = scaler.fit_transform(numeric_features)

# %%
numeric_features_scaled
# Out:
# array([[ 0.4463504 ,  1.15325359, -2.49382042, -0.08476639, -0.12383237],
#        [ 1.32236521, -0.66085318,  0.33809616, -0.2830722 ,  0.67807769],
#        [ 0.008343  ,  0.2462002 ,  0.33809616, -0.98162336, -1.32669745],
#        ...,
#        [-1.08667552, -0.66085318,  0.33809616, -0.05052819, -0.12383237],
#        [ 1.32236521, -0.66085318, -1.07786213, -0.22332769,  0.47760017],
#        [-0.32016256,  0.2462002 ,  1.75405446, -0.44989724, -0.5247874 ]])

# %%
numeric_features_scaled = pd.DataFrame(numeric_features_scaled, columns=numeric_features.columns, index=numeric_features.index)

# %%
numeric_features_scaled
# Out:
#            Age  JobSatisfaction  WorkLifeBalance  MonthlyIncome  \
# 0     0.446350         1.153254        -2.493820      -0.084766
# 1     1.322365        -0.660853         0.338096      -0.283072
# 2     0.008343         0.246200         0.338096      -0.981623
# 3    -0.429664         0.246200         0.338096      -0.793428
# 4    -1.086676        -0.660853         0.338096      -0.664977
# ...        ...              ...              ...            ...
# 1465 -0.101159         1.153254         0.338096      -0.871096
# 1466  0.227347        -1.567907         0.338096       0.833920
# 1467 -1.086676        -0.660853         0.338096      -0.050528
# 1468  1.322365        -0.660853        -1.077862      -0.223328
# 1469 -0.320163         0.246200         1.754054      -0.449897
#
#       YearsAtCompany
# 0          -0.123832
# 1           0.678078
# 2          -1.326697
# 3           0.277123
# 4          -0.925742
# ...              ...
# 1465       -0.324310
# ...

# %% [markdown]
# # 7. Encoding Categorical Features
# * Label Encoding: For ordinal data
# * One-Hot Encoding: For nominal data

# %%
categorical_features = pd.get_dummies(categorical_features, columns=categorical_features.columns)

# %%
categorical_features
# Out:
#       BusinessTravel_Non-Travel  BusinessTravel_Travel_Frequently  \
# 0                         False                             False
# 1                         False                              True
# 2                         False                             False
# 3                         False                              True
# 4                         False                             False
# ...                         ...                               ...
# 1465                      False                              True
# 1466                      False                             False
# 1467                      False                             False
# 1468                      False                              True
# 1469                      False                             False
#
#       BusinessTravel_Travel_Rarely  Department_Human Resources  \
# 0                             True                       False
# ...

# %%
Features = pd.concat([numeric_features_scaled, categorical_features], axis=1 )

# %%
Features
# Out:
#            Age  JobSatisfaction  WorkLifeBalance  MonthlyIncome  \
# 0     0.446350         1.153254        -2.493820      -0.084766
# 1     1.322365        -0.660853         0.338096      -0.283072
# 2     0.008343         0.246200         0.338096      -0.981623
# 3    -0.429664         0.246200         0.338096      -0.793428
# 4    -1.086676        -0.660853         0.338096      -0.664977
# ...        ...              ...              ...            ...
# 1465 -0.101159         1.153254         0.338096      -0.871096
# 1466  0.227347        -1.567907         0.338096       0.833920
# 1467 -1.086676        -0.660853         0.338096      -0.050528
# 1468  1.322365        -0.660853        -1.077862      -0.223328
# 1469 -0.320163         0.246200         1.754054      -0.449897
#
#       YearsAtCompany  BusinessTravel_Non-Travel  \
# 0          -0.123832                      False
# 1           0.678078                      False
# 2          -1.326697                      False
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create correlation matrix
plt.figure(figsize=(20, 16))
sns.heatmap(Features.corr(), annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Matrix of  Features', pad=20)
plt.tight_layout()
plt.show()

# %%
# For better readability, let's also show the most significant correlations
threshold = 0.5  # Show correlations above 0.5 or below -0.5
correlations = Features.corr()
high_correlations = (correlations.abs() > threshold) & (correlations != 1.0)
print("\nStrong Correlations (above |0.5|):")
for col in correlations.columns:
    corr_pairs = correlations[high_correlations][col].dropna()
    if not corr_pairs.empty:
        print(f"\n{col} is strongly correlated with:")
        for idx, value in corr_pairs.items():
            print(f"- {idx}: {value:.3f}")
# Out:
# Strong Correlations (above |0.5|):
#
# BusinessTravel_Non-Travel is strongly correlated with:
# - BusinessTravel_Travel_Rarely: -0.527
#
# BusinessTravel_Travel_Frequently is strongly correlated with:
# - BusinessTravel_Travel_Rarely: -0.753
#
# BusinessTravel_Travel_Rarely is strongly correlated with:
# - BusinessTravel_Non-Travel: -0.527
# - BusinessTravel_Travel_Frequently: -0.753
#
# Department_Research & Development is strongly correlated with:
# - Department_Sales: -0.907
#
# Department_Sales is strongly correlated with:
# - Department_Research & Development: -0.907

# %% [markdown]
# # 8. Handling Imbalanced Data
# ### Techniques
# * Resampling (oversample using SMOTE)
#
# #### SMOTE -> Synthetic data generation

# %%
# Handle Imbalanced Data using SMOTE
from imblearn.over_sampling import SMOTE
from collections import Counter
import numpy as np

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
# Encode target variable
Target_encoded = le.fit_transform(Target)

# Initialize SMOTE
smote = SMOTE(random_state=42)

# Apply SMOTE
X_balanced, y_balanced = smote.fit_resample(Features, Target_encoded)

# Convert y_balanced back to original labels
y_balanced = le.inverse_transform(y_balanced)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# Print the distribution before and after SMOTE
print("Distribution before SMOTE:")
print(pd.DataFrame(Target).value_counts())
print("\nDistribution after SMOTE:")
print(pd.DataFrame(y_balanced).value_counts())


plt.figure(figsize=(12, 5))

# Before SMOTE
plt.subplot(1, 2, 1)
Target.value_counts().plot(kind='bar')
plt.title('Class Distribution Before SMOTE')
plt.xlabel('Attrition')
plt.ylabel('Count')

# After SMOTE
plt.subplot(1, 2, 2)
pd.DataFrame(y_balanced).value_counts().plot(kind='bar')
plt.title('Class Distribution After SMOTE')
plt.xlabel('Attrition')
# Out:
# Distribution before SMOTE:
# Attrition
# No           1233
# Yes           237
# Name: count, dtype: int64
#
# Distribution after SMOTE:
# 0
# No     1233
# Yes    1233
# Name: count, dtype: int64
# Text(0.5, 0, 'Attrition')

# %%
X_balanced
# Out:
#            Age  JobSatisfaction  WorkLifeBalance  MonthlyIncome  \
# 0     0.446350         1.153254        -2.493820      -0.084766
# 1     1.322365        -0.660853         0.338096      -0.283072
# 2     0.008343         0.246200         0.338096      -0.981623
# 3    -0.429664         0.246200         0.338096      -0.793428
# 4    -1.086676        -0.660853         0.338096      -0.664977
# ...        ...              ...              ...            ...
# 2461 -0.723767         0.544208        -1.077862      -0.941566
# 2462 -0.285459         1.153254        -1.077862      -0.233185
# 2463 -0.482546         1.153254         0.509047      -0.640508
# 2464 -1.658790        -0.660853         0.338096      -0.815221
# 2465 -0.637296        -1.567907         0.338096      -0.724747
#
#       YearsAtCompany  BusinessTravel_Non-Travel  \
# 0          -0.123832                      False
# 1           0.678078                      False
# 2          -1.326697                      False
# ...

# %%
y_balanced
# Out:
# array(['Yes', 'No', 'Yes', ..., 'Yes', 'Yes', 'Yes'], dtype=object)

# %%
Features = X_balanced
Target = pd.DataFrame(y_balanced, columns=['Attrition'])

# %%
Features
# Out:
#            Age  JobSatisfaction  WorkLifeBalance  MonthlyIncome  \
# 0     0.446350         1.153254        -2.493820      -0.084766
# 1     1.322365        -0.660853         0.338096      -0.283072
# 2     0.008343         0.246200         0.338096      -0.981623
# 3    -0.429664         0.246200         0.338096      -0.793428
# 4    -1.086676        -0.660853         0.338096      -0.664977
# ...        ...              ...              ...            ...
# 2461 -0.723767         0.544208        -1.077862      -0.941566
# 2462 -0.285459         1.153254        -1.077862      -0.233185
# 2463 -0.482546         1.153254         0.509047      -0.640508
# 2464 -1.658790        -0.660853         0.338096      -0.815221
# 2465 -0.637296        -1.567907         0.338096      -0.724747
#
#       YearsAtCompany  BusinessTravel_Non-Travel  \
# 0          -0.123832                      False
# 1           0.678078                      False
# 2          -1.326697                      False
# ...

# %%
Target
# Out:
#      Attrition
# 0          Yes
# 1           No
# 2          Yes
# 3           No
# 4           No
# ...        ...
# 2461       Yes
# 2462       Yes
# 2463       Yes
# 2464       Yes
# 2465       Yes
#
# [2466 rows x 1 columns]

# %%
data1 = pd.concat([Features, Target], axis=1)
data1
# Out:
#            Age  JobSatisfaction  WorkLifeBalance  MonthlyIncome  \
# 0     0.446350         1.153254        -2.493820      -0.084766
# 1     1.322365        -0.660853         0.338096      -0.283072
# 2     0.008343         0.246200         0.338096      -0.981623
# 3    -0.429664         0.246200         0.338096      -0.793428
# 4    -1.086676        -0.660853         0.338096      -0.664977
# ...        ...              ...              ...            ...
# 2461 -0.723767         0.544208        -1.077862      -0.941566
# 2462 -0.285459         1.153254        -1.077862      -0.233185
# 2463 -0.482546         1.153254         0.509047      -0.640508
# 2464 -1.658790        -0.660853         0.338096      -0.815221
# 2465 -0.637296        -1.567907         0.338096      -0.724747
#
#       YearsAtCompany  BusinessTravel_Non-Travel  \
# 0          -0.123832                      False
# 1           0.678078                      False
# 2          -1.326697                      False
# ...

# %% [markdown]
# # 9. Train-Test Split

# %%
x = data1.drop('Attrition', axis=1)
y = data1[['Attrition']]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
# Import required models
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# Initialize models
rf_model = RandomForestClassifier(random_state=42)
svm_model = SVC(random_state=42)
nb_model = GaussianNB()
dt_model = DecisionTreeClassifier(random_state=42)
lr_model = LogisticRegression(random_state=42)

# %% [markdown]
# # 1 Random Forest Model

# %%
# Train Random Forest model
rf_model.fit(x_train, y_train)

# Get model score
rf_score = rf_model.score(x_test, y_test)
print("Random Forest Model Score:", rf_score)

# Make predictions
y_pred = rf_model.predict(x_test)

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap='Blues')
plt.title('Random Forest Confusion Matrix')
plt.show()

# Print detailed classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Random Forest Model Score: 0.8947368421052632
# Classification Report:
#               precision    recall  f1-score   support
#
#           No       0.88      0.91      0.90       250
#          Yes       0.91      0.88      0.89       244
#
#     accuracy                           0.89       494
#    macro avg       0.90      0.89      0.89       494
# weighted avg       0.90      0.89      0.89       494

# %% [markdown]
# # 2 support Vectore Machine model

# %%
# Train support Vectore Machine model
svm_model.fit(x_train, y_train)

# Get model score
svm_score = svm_model.score(x_test, y_test)
print("Random Forest Model Score:", rf_score)

# Make predictions
y_pred = svm_model.predict(x_test)

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap='Blues')
plt.title('support Vectore Machine Confusion Matrix')
plt.show()

# Print detailed classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Random Forest Model Score: 0.8947368421052632
# Classification Report:
#               precision    recall  f1-score   support
#
#           No       0.78      0.73      0.75       250
#          Yes       0.74      0.79      0.76       244
#
#     accuracy                           0.76       494
#    macro avg       0.76      0.76      0.76       494
# weighted avg       0.76      0.76      0.76       494

# %% [markdown]
# # 3 Naive Byse model

# %%
# Train Naive Byse model
nb_model.fit(x_train, y_train)

# Get model score
nb_score = nb_model.score(x_test, y_test)
print("Random Forest Model Score:", rf_score)

# Make predictions
y_pred = nb_model.predict(x_test)

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap='Blues')
plt.title('Naive Byse Confusion Matrix')
plt.show()

# Print detailed classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Random Forest Model Score: 0.8947368421052632
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Classification Report:
#               precision    recall  f1-score   support
#
#           No       0.67      0.48      0.56       250
#          Yes       0.59      0.75      0.66       244
#
#     accuracy                           0.62       494
#    macro avg       0.63      0.62      0.61       494
# weighted avg       0.63      0.62      0.61       494

# %% [markdown]
# # 4 Decision Tree model

# %%
# Train Decision Tree model
dt_model.fit(x_train, y_train)

# Get model score
dt_score = dt_model.score(x_test, y_test)
print("Random Forest Model Score:", rf_score)

# Make predictions
y_pred = dt_model.predict(x_test)

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap='Blues')
plt.title('Decision Tree Confusion Matrix')
plt.show()

# Print detailed classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Random Forest Model Score: 0.8947368421052632
# Classification Report:
#               precision    recall  f1-score   support
#
#           No       0.81      0.79      0.80       250
#          Yes       0.79      0.81      0.80       244
#
#     accuracy                           0.80       494
#    macro avg       0.80      0.80      0.80       494
# weighted avg       0.80      0.80      0.80       494

# %% [markdown]
# # 5 Logistic Regression model

# %%
# Train Logistic Regression model
lr_model.fit(x_train, y_train)

# Get model score
lr_score = lr_model.score(x_test, y_test)
print("Random Forest Model Score:", rf_score)

# Make predictions
y_pred = lr_model.predict(x_test)

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap='Blues')
plt.title('Logistic Regression Confusion Matrix')
plt.show()

# Print detailed classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Random Forest Model Score: 0.8947368421052632
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Classification Report:
#               precision    recall  f1-score   support
#
#           No       0.73      0.72      0.72       250
#          Yes       0.72      0.73      0.72       244
#
#     accuracy                           0.72       494
#    macro avg       0.72      0.72      0.72       494
# weighted avg       0.72      0.72      0.72       494

# %% [markdown]
# # Final deployment

# %%
# Save the models and scaler using joblib
from joblib import dump

# Save Random Forest model
dump(rf_model, 'random_forest_model.joblib')

# Save the scaler
dump(scaler, 'scaler.joblib')

print("Models and scaler saved successfully!")
# Out:
# Models and scaler saved successfully!

# %%
# Load the saved models and scaler
from joblib import load

# Load the models and scaler
rf_model = load('random_forest_model.joblib')
scaler = load('scaler.joblib')

# %%
data1
# Out:
#            Age  JobSatisfaction  WorkLifeBalance  MonthlyIncome  \
# 0     0.446350         1.153254        -2.493820      -0.084766
# 1     1.322365        -0.660853         0.338096      -0.283072
# 2     0.008343         0.246200         0.338096      -0.981623
# 3    -0.429664         0.246200         0.338096      -0.793428
# 4    -1.086676        -0.660853         0.338096      -0.664977
# ...        ...              ...              ...            ...
# 2461 -0.723767         0.544208        -1.077862      -0.941566
# 2462 -0.285459         1.153254        -1.077862      -0.233185
# 2463 -0.482546         1.153254         0.509047      -0.640508
# 2464 -1.658790        -0.660853         0.338096      -0.815221
# 2465 -0.637296        -1.567907         0.338096      -0.724747
#
#       YearsAtCompany  BusinessTravel_Non-Travel  \
# 0          -0.123832                      False
# 1           0.678078                      False
# 2          -1.326697                      False
# ...

# %%
data
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      41       Yes      Travel_Rarely                   Sales
# 1      49        No  Travel_Frequently  Research & Development
# 2      37       Yes      Travel_Rarely  Research & Development
# 3      33        No  Travel_Frequently  Research & Development
# 4      27        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 1465   36        No  Travel_Frequently  Research & Development
# 1466   39        No      Travel_Rarely  Research & Development
# 1467   27        No      Travel_Rarely  Research & Development
# 1468   49        No  Travel_Frequently                   Sales
# 1469   34        No      Travel_Rarely  Research & Development
#
#       JobSatisfaction  WorkLifeBalance  MonthlyIncome  YearsAtCompany
# 0                   4                1           5993               6
# ...

# %%
data['JobSatisfaction'].unique() ,data['WorkLifeBalance'].unique() , data['BusinessTravel'].unique() , data['Department'].unique()
# Out:
# (array([4, 2, 3, 1]),
#  array([1, 3, 2, 4]),
#  array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object),
#  array(['Sales', 'Research & Development', 'Human Resources'], dtype=object))

# %%
columns = [
    "Age",
    "JobSatisfaction",
    "WorkLifeBalance",
    "MonthlyIncome",
    "YearsAtCompany",
    "BusinessTravel_Non-Travel",
    "BusinessTravel_Travel_Frequently",
    "BusinessTravel_Travel_Rarely",
    "Department_Human Resources",
    "Department_Research & Development",
    "Department_Sales"
]

# Create an empty DataFrame
new_data = pd.DataFrame(columns=columns)

new_data
# Out:
# Empty DataFrame
# Columns: [Age, JobSatisfaction, WorkLifeBalance, MonthlyIncome, YearsAtCompany, BusinessTravel_Non-Travel, BusinessTravel_Travel_Frequently, BusinessTravel_Travel_Rarely, Department_Human Resources, Department_Research & Development, Department_Sales]
# Index: []

# %%
# Take input from the user
Age = input("Enter Age: ")
JobSatisfaction = input("Enter JobSatisfaction (4, 2, 3, 1): ")
WorkLifeBalance = input("Enter WorkLifeBalance (4, 2, 3, 1): ")
MonthlyIncome = input("Enter MonthlyIncome: ")
YearsAtCompany = input("Enter YearsAtCompany: ")
BusinessTravel = input("Enter BusinessTravel (Travel_Rarely, Travel_Frequently, Non-Travel): ")
Department = input("Enter Department (Sales, Research & Development, Human Resources): ")

# Create a new row with numerical features (ensure to convert to float as needed)
new_numerical = [[float(Age), float(JobSatisfaction), float(WorkLifeBalance), float(MonthlyIncome), float(YearsAtCompany)]]

# Scale the new data
new_numerical_scal = scaler.transform(new_numerical)

# Create a new row with categorical data
new_categorical = {
    "BusinessTravel_Non-Travel": False,
    "BusinessTravel_Travel_Frequently": False,
    "BusinessTravel_Travel_Rarely": False,
    "Department_Human Resources": False,
    "Department_Research & Development": False,
    "Department_Sales": False
}

# Handle BusinessTravel categories
if BusinessTravel == 'Travel_Rarely':
    new_categorical["BusinessTravel_Travel_Rarely"] = True
elif BusinessTravel == 'Travel_Frequently':
    new_categorical["BusinessTravel_Travel_Frequently"] = True
elif BusinessTravel == 'Non-Travel':
    new_categorical["BusinessTravel_Non-Travel"] = True

# Handle Department categories
if Department == 'Sales':
    new_categorical["Department_Sales"] = True
elif Department == 'Research & Development':
    new_categorical["Department_Research & Development"] = True
elif Department == 'Human Resources':
    new_categorical["Department_Human Resources"] = True

# Combine the numerical and categorical data
new_row = new_numerical_scal[0].tolist() + list(new_categorical.values())

# Append the new row to the DataFrame
new_data.loc[len(new_data)] = new_row

new_data

# %%
prediction = rf_model.predict(new_data)
print(prediction)
